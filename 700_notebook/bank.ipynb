# %%
import pandas as pd
import numpy as np

# %%
# 設定
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('data/bank/train.csv')

# %%
df.head()
# Out:
#    id  age           job  marital  education default  balance housing loan  \
# 0   0   31      services  married  secondary      no    12294     yes   no
# 1   1   29  entrepreneur   single   tertiary      no    43027      no   no
# 2   2   35    management  married   tertiary      no    12252     yes   no
# 3   3   31    technician  married  secondary      no    99121     yes  yes
# 4   4   48    unemployed  married    primary      no    42005     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  y
# 0   cellular   21   nov       101         3    498         0    other  0
# 1   cellular   22   aug       158         2    702         0  unknown  1
# 2   cellular   11   nov       351         1    826         0  failure  0
# 3    unknown   16   may       658         2    120         0  failure  0
# 4  telephone    3   apr       177         1    273         0  unknown  0

# %%
# calumnsの分類
c_int = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
c_yn = ['marital', 'default', 'housing', 'loan']
c_sel = ['job', 'education', 'contact', 'month', 'poutcome']

# %%
df.shape
# Out:
# (27100, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27100 entries, 0 to 27099
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         27100 non-null  int64
#  1   age        27100 non-null  int64
#  2   job        27100 non-null  object
#  3   marital    27100 non-null  object
#  4   education  27100 non-null  object
#  5   default    27100 non-null  object
#  6   balance    27100 non-null  int64
#  7   housing    27100 non-null  object
#  8   loan       27100 non-null  object
#  9   contact    27100 non-null  object
#  10  day        27100 non-null  int64
#  11  month      27100 non-null  object
#  12  duration   27100 non-null  int64
#  13  campaign   27100 non-null  int64
#  14  pdays      27100 non-null  int64
#  15  previous   27100 non-null  int64
#  16  poutcome   27100 non-null  object
#  17  y          27100 non-null  int64
# dtypes: int64(9), object(9)
# memory usage: 3.7+ MB

# %%
df[c_int].describe()
# Out:
#            age   balance      day  duration  campaign    pdays  previous
# count 27100.00  27100.00 27100.00  27100.00  27100.00 27100.00  27100.00
# mean     36.07  47682.90    16.75    229.33      1.78   432.48      0.09
# std       7.82  31650.76     8.57    204.94      0.95   252.15      0.37
# min      22.00  -6847.00     1.00      0.00      1.00    -1.00      0.00
# 25%      31.00  20015.75     8.00    121.00      1.00   214.00      0.00
# 50%      33.00  47624.00    17.00    158.00      1.00   432.00      0.00
# 75%      37.00  75330.00    26.00    345.00      2.00   650.00      0.00
# max      90.00 102121.00    31.00   3076.00      5.00   870.00      3.00

# %%
df.isnull().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.rename(columns={'age':'年齢', 'balance':'残高'})
# オプションにinplace=Trueを付ければdfの上書きができる
# Out:
#           id  年齢           job  marital  education default     残高 housing  \
# 0          0  31      services  married  secondary      no  12294     yes
# 1          1  29  entrepreneur   single   tertiary      no  43027      no
# 2          2  35    management  married   tertiary      no  12252     yes
# 3          3  31    technician  married  secondary      no  99121     yes
# 4          4  48    unemployed  married    primary      no  42005     yes
# ...      ...  ..           ...      ...        ...     ...    ...     ...
# 27095  27095  37   blue-collar  married  secondary      no  26661     yes
# 27096  27096  35      services  married  secondary      no  42150     yes
# 27097  27097  35      services  married    unknown      no  34531      no
# 27098  27098  30        admin.   single  secondary      no  99621     yes
# 27099  27099  34    management  married   tertiary      no   8657     yes
#
#       loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
df.sort_values(by=['age', 'balance'], ascending=True)
# Out:
#           id  age           job   marital  education default  balance housing  \
# 4539    4539   22       student    single  secondary      no    -4554      no
# 9139    9139   24       student    single    unknown      no     3880     yes
# 26502  26502   24   blue-collar    single  secondary      no    11623      no
# 5376    5376   24   blue-collar   married    primary      no    12928      no
# 8584    8584   24   blue-collar   married  secondary      no    25676      no
# ...      ...  ...           ...       ...        ...     ...      ...     ...
# 24981  24981   90       retired   married  secondary      no    34392      no
# 3107    3107   90      services   married  secondary      no    44991     yes
# 25669  25669   90       retired   married    primary      no    71671     yes
# 12372  12372   90  entrepreneur  divorced  secondary      no    88889     yes
# 11633  11633   90      services  divorced  secondary      no    90530      no
#
# ...

# %%
df[df['default'] == 'yes']
# Out:
#           id  age          job   marital  education default  balance housing  \
# 1536    1536   39   management   married   tertiary     yes    -5667      no
# 8073    8073   35   technician  divorced  secondary     yes    84123      no
# 13800  13800   35   technician  divorced    primary     yes    61432     yes
# 17035  17035   29      student    single  secondary     yes    65715      no
# 19353  19353   32   unemployed   married  secondary     yes    65580     yes
# 19839  19839   32  blue-collar   married    primary     yes    32794     yes
# 20423  20423   31  blue-collar   married    primary     yes    86231     yes
# 23114  23114   47  blue-collar  divorced  secondary     yes    59603      no
# 25086  25086   31  blue-collar    single  secondary     yes    26203     yes
# 25461  25461   30     services   married  secondary     yes    71305     yes
#
#       loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
df[df['balance'] < 0]
# Out:
#           id  age            job  marital  education default  balance housing  \
# 5          5   30    blue-collar  married    primary      no    -6160      no
# 42        42   32  self-employed   single  secondary      no    -3882      no
# 69        69   34    blue-collar   single  secondary      no    -2138     yes
# 81        81   34         admin.   single  secondary      no    -4878     yes
# 84        84   60        retired  married    unknown      no     -630     yes
# ...      ...  ...            ...      ...        ...     ...      ...     ...
# 26938  26938   34     management  married  secondary      no    -2226     yes
# 26970  26970   35     unemployed  married  secondary      no    -4537     yes
# 26991  26991   30     unemployed   single  secondary      no     -874     yes
# 27008  27008   33    blue-collar  married  secondary      no    -4449     yes
# 27051  27051   33         admin.  married  secondary      no     -682      no
#
# ...

# %%
df['job'].unique()
# Out:
# array(['services', 'entrepreneur', 'management', 'technician',
#        'unemployed', 'blue-collar', 'admin.', 'retired', 'self-employed',
#        'housemaid', 'student'], dtype=object)

# %%
df['job'].value_counts()
# Out:
# blue-collar      5957
# management       5346
# technician       4915
# admin.           3187
# services         2471
# self-employed    1163
# entrepreneur     1155
# retired          1004
# unemployed        795
# housemaid         754
# student           353
# Name: job, dtype: int64

# %%
df_yn = pd.DataFrame({
    'housing':['yes', 'no'],
    'housing_01':[0, 1]
})

# %%
df_yn
# Out:
#   housing  housing_01
# 0     yes           0
# 1      no           1

# %%
pd.merge(df, df_yn, on='housing')
# Out:
#           id  age            job   marital  education default  balance  \
# 0          0   31       services   married  secondary      no    12294
# 1          2   35     management   married   tertiary      no    12252
# 2          3   31     technician   married  secondary      no    99121
# 3          4   48     unemployed   married    primary      no    42005
# 4          6   33    blue-collar   married  secondary      no    88282
# ...      ...  ...            ...       ...        ...     ...      ...
# 27095  27084   28  self-employed    single   tertiary      no     3856
# 27096  27085   31       services  divorced  secondary      no    33858
# 27097  27088   29         admin.    single  secondary      no    38024
# 27098  27093   60     unemployed    single   tertiary      no    72292
# 27099  27097   35       services   married    unknown      no    34531
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...
