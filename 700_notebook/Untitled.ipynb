# %%
import pandas as pd

# %%
df = pd.read_csv('../200_input/pma_jo_sho_item.csv')

# %%
df
# Out:
#        pma  pma_name jo    jo_name  sho   sho_name    item  \
# 0        1       ビール  A     瓶・樽ビール    2         大瓶   10105
# 1        1       ビール  A     瓶・樽ビール    2         大瓶   10108
# 2        1       ビール  A     瓶・樽ビール    2         大瓶   10239
# 3        1       ビール  A     瓶・樽ビール    2         大瓶   10349
# 4        1       ビール  A     瓶・樽ビール    2         大瓶   10354
# ...    ...       ... ..        ...  ...        ...     ...
# 63002   86  試食・試飲・展示  P      試食・菓子    2  ポケット・洋風菓子  860765
# 63003   86  試食・試飲・展示  R    試食・冷凍食品    1       調理食品  860904
# 63004   86  試食・試飲・展示  S  試食・ギフト・進物    1       夏ギフト  860019
# 63005   86  試食・試飲・展示  S  試食・ギフト・進物    1       夏ギフト  860898
# 63006   86  試食・試飲・展示  S  試食・ギフト・進物    2       冬ギフト  860025
#
#                     item_name  sdate_ymd  edate_ymd  hachu_tani  kakaku  \
# 0      アサヒ　スーパードライ大瓶　　　　６３３ＭＬ   20200921   99999999           1     367
# 1      サッポロ　黒ラベル大瓶　　　　　　６３３ＭＬ   20200921   99999999           1     367
# ...

# %%
df['pma_name'].unique()
# Out:
# array(['ビール', '日本酒', '洋酒・ワイン・雑酒', '米飯', '調理パン', '麺類・その他', 'デリカテッセン',
#        'スイーツ', 'ＦＦおでん', 'ＦＦカップ', 'カウントＦＦ', 'ＦＦフライヤーその他', '牛乳・乳飲料', '乳製品',
#        '玉子', '生活デイリー', 'パン', 'ペストリー', '和風菓子・豆菓子', 'ポケット・洋風菓子', 'スナック菓子',
#        '加工食品', '調味料・乾物', '米穀', 'し好品', '珍味・缶詰', '冷凍食品', 'アイスクリーム',
#        'ソフトドリンク', '栄養ドリンク', '健康栄養食品', '催事・進物ギフト', 'くらしのギフト', 'ネット（出版その他）',
#        'お中元ギフト', 'お歳暮ギフト', '文庫・書籍', 'タバコ', '雑誌', '新聞', 'コミックス',
#        '映像・音楽ソフト', '軽衣料', '健康・医療品', '紙・生理用品', 'オーラル・シャンプー', '洗剤・防虫・芳香',
#        '生活雑貨・行楽用品', '化粧品', '玩具', '文具', 'その他雑貨', '切手葉書印紙', 'サービス商品',
#        '委託商品', 'クーポン', '消耗品', '試食・試飲・展示'], dtype=object)
